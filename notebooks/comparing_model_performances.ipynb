# %% [markdown]
# # comparing_model_performances.ipynb
#
# This notebook strictly compares the model performances of various models (PCA and non-PCA).
# I will have a couple visuals to see.

# %%
# Importing libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

pd.options.display.float_format = '{:.5f}'.format
# %matplotlib inline

# %%
# Getting the performances
models_no_pca = pd.read_csv('/Users/jinalshah/Jinal/Projects/march-madness-mania/model-performances/metrics_no_pca.csv',index_col=0)
models_with_pca = pd.read_csv('/Users/jinalshah/Jinal/Projects/march-madness-mania/model-performances/metrics_pca.csv',index_col=0)

# Looking at the non-PCA model performances
models_no_pca
# Out:
#                          Model  Log Loss Train  Log Loss CV  \
# 0             Dummy-Classifier         0.69315      0.69315
# 1  Vanilla-Logistic-Regression         0.49605      0.66254
# 2                Decision-Tree         0.00000     14.81158
# 3                Random-Forest         0.24254      0.60001
# 4            AdaBoost-Logistic         0.69239      0.69251
# 5       AdaBoost-Decision-Tree         0.00000     15.39553
# 6  Logistic-Regression-Elastic         0.50272      0.61906
# 7              Logistic-and-RF         0.33946      0.58827
# 8             Vanilla-Catboost         0.01721      0.76844
# 9               Neural Network         7.91163      7.91163
#
#    Brier Score Training  Mean Brier Score CV  Accuracy Training  \
# 0               0.25000              0.25000            0.51681
# 1               0.16507              0.22290            0.76526
# 2               0.00000              0.41093            1.00000
# ...

# %%
# Looking at the PCA model performance
models_with_pca
# Out:
#                              Model  Log Loss Train  Log Loss CV  \
# 0             Dummy-Classifier-PCA         0.69315      0.69315
# 1  Vanilla-Logistic-Regression-PCA         0.53834      0.60250
# 2                Decision-Tree-PCA         0.00000     13.98122
# 3                Random-Forest-PCA         0.26344      0.63894
# 4            AdaBoost-Logistic-PCA         0.69258      0.69263
# 5       AdaBoost-Decision-Tree-PCA         0.00000     14.60877
# 6  Logistic-Regression-Elastic-PCA         0.53886      0.59970
# 7              Logistic-and-RF-PCA         0.37232      0.59815
# 8             Vanilla-Catboost-PCA         0.01716      0.71374
# 9               Neural Network-PCA         7.91163      7.91163
#
#    Brier Score Training  Mean Brier Score CV  Accuracy Training  \
# 0               0.25000              0.25000            0.51681
# 1               0.18351              0.20904            0.71046
# 2               0.00000              0.38790            1.00000
# ...
